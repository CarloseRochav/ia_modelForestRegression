# %%
import pandas as pd

# Carga el CSV a un dataframe
df = pd.read_csv("../data/tableClaude.csv")

# Agrega una nueva columna antes de "sem1"
#df.insert(0, "periodo", range(1, 23))

# Imprime el dataframe
#print(df)

# %%
df
# Out:
#     sem1  sem2  sem3  sem4  sem5  sem6  sem7  sem8  sem9
# 0      0    15    18    12    18     0     0     0     0
# 1      2    24    19    13    14    12     0     0     0
# 2      3    19    22    17    12    12    12    10     0
# 3      1    19    18    18    12    12    13    15     2
# 4      4    19    18    18    12    12    14    15     2
# 5      2    32    18    18    17    12    12    12     7
# 6      2    14    24    17    18    14    12    11     6
# 7      1    26    14    23    16    18    12    12     5
# 8      2    22    13    22    18    14    19    13     4
# 9      2    25    15    13    12    14    12    12     6
# 10     2    24    21    12    18    12    13    11     8
# 11     2    25    19    17    12    17    10    12     8
# 12     3    20    21    16    18    12    16    15    13
# 13     4    22    18    18    12    12    10    15    11
# 14     3    21    19    18    17    12    18    15    11
# ...

# %%
# 1. Importar librerías
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import numpy as np

# Cargar datos
df = pd.read_csv('datos.csv')

# Entrenar modelo 
X = df.drop('Sem9', axis=1)
y = df['Sem9']

rf = RandomForestRegressor()
rf.fit(X, y)

# Predecir en datos de entrenamiento
predictions = rf.predict(X)

# Mostrar predicciones
for i in range(9):
  print(f"Semestre {i+1}: {predictions[i]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 import numpy as np
#       8 # Cargar datos
# ----> 9 df = pd.read_csv('datos.csv')
#      11 # Entrenar modelo
#      12 X = df.drop('Sem9', axis=1)
#
# ...
